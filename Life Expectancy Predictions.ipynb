# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
life_expect_df = pd.read_excel('Life expectancy.xlsx')
life_expect_df
# Out:
#           Country  Year  Life expectancy at birth (years)  \
# 0              UK  2021                              80.1
# 1              UK  2020                              80.1
# 2              UK  2019                              81.2
# 3              UK  2018                              80.6
# 4              UK  2017                              80.9
# ..            ...   ...                               ...
# 215  SAUDI ARABIA  2004                              71.6
# 216  SAUDI ARABIA  2003                              71.3
# 217  SAUDI ARABIA  2002                              71.1
# 218  SAUDI ARABIA  2001                              70.8
# 219  SAUDI ARABIA  2000                              70.6
#
#      Hospital beds (per 10 000 population)  \
# 0                                     23.5
# 1                                     24.3
# 2                                     24.5
# 3                                     25.0
# 4                                     25.4
# ..                                     ...
# 215                                   21.6
# 216                                   21.2
# 217                                   20.8
# 218                                    NaN
# 219                                    NaN
#
#      Incidence of tuberculosis (per 100 000 population per year)  \
# 0                                                  8.0
# 1                                                  7.0
# 2                                                  8.1
# 3                                                  8.0
# 4                                                  8.9
# ..                                                 ...
# 215                                               19.0
# 216                                               19.0
# 217                                               21.0
# 218                                               21.0
# 219                                               23.0
#
#      Infant mortality rate (between birth and 11 months per 1000 live births)  \
# 0                                                  3.9
# 1                                                  3.9
# 2                                                  3.8
# 3                                                  3.8
# 4                                                  3.8
# ..                                                 ...
# 215                                               15.5
# 216                                               16.5
# 217                                               17.6
# 218                                               18.7
# 219                                               19.9
#
#      Population using at least basic drinking-water services (%)  \
# 0                                                100.0
# 1                                                100.0
# 2                                                100.0
# 3                                                100.0
# 4                                                100.0
# ..                                                 ...
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
#
#      Population using safely managed sanitation services (%)  \
# 0                                                   98
# 1                                                   98
# 2                                                   98
# 3                                                   98
# 4                                                   98
# ..                                                 ...
# 215                                                 79
# 216                                                 79
# 217                                                 79
# 218                                                 79
# 219                                                 79
#
#      Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)  \
# 0                                                12.02
# 1                                                11.97
# 2                                                 9.95
# 3                                                 9.74
# 4                                                 9.60
# ..                                                 ...
# 215                                               3.58
# 216                                               3.98
# 217                                               4.25
# 218                                               4.46
# 219                                               4.21
#
#      Fertility rate total (births per woman)
# 0                                        1.6
# 1                                        1.6
# 2                                        1.6
# 3                                        1.7
# 4                                        1.7
# ..                                       ...
# 215                                      3.3
# 216                                      3.5
# 217                                      3.7
# 218                                      4.0
# 219                                      4.2
#
# [220 rows x 10 columns]

# %%
life_expect_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 10 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   Country                                                                             220 non-null    object
#  1   Year                                                                                220 non-null    int64
#  2   Life expectancy at birth (years)                                                    220 non-null    float64
#  3   Hospital beds (per 10 000 population)                                               190 non-null    float64
#  4   Incidence of tuberculosis (per 100 000 population per year)                         220 non-null    float64
#  5   Infant mortality rate (between birth and 11 months per 1000 live births)            220 non-null    float64
#  6   Population using at least basic drinking-water services (%)                         198 non-null    float64
#  7   Population using safely managed sanitation services (%)                             220 non-null    int64
#  8   Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)  220 non-null    float64
#  9   Fertility rate total (births per woman)                                             220 non-null    float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 17.3+ KB

# %%
life_expect_df.isna().sum()
# Out:
# Country                                                                                0
# Year                                                                                   0
# Life expectancy at birth (years)                                                       0
# Hospital beds (per 10 000 population)                                                 30
# Incidence of tuberculosis (per 100 000 population per year)                            0
# Infant mortality rate (between birth and 11 months per 1000 live births)               0
# Population using at least basic drinking-water services (%)                           22
# Population using safely managed sanitation services (%)                                0
# Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)     0
# Fertility rate total (births per woman)                                                0
# dtype: int64

# %% [markdown]
# Convert the column to numeric, coercing errors to Nan

# %%
life_expect_df['Hospital beds (per 10 000 population)'] = pd.to_numeric(life_expect_df['Hospital beds (per 10 000 population)'], errors='coerce')

# filling NaN values by calculating mean value
mean_value_bed = life_expect_df['Hospital beds (per 10 000 population)'].mean()
mean_value_water = life_expect_df['Population using at least basic drinking-water services (%)'].mean()
life_expect_df['Hospital beds (per 10 000 population)'].fillna(mean_value_bed, inplace=True)
life_expect_df['Population using at least basic drinking-water services (%)'].fillna(mean_value_water, inplace=True)
life_expect_df.isna().sum()
# Out:
# Country                                                                               0
# Year                                                                                  0
# Life expectancy at birth (years)                                                      0
# Hospital beds (per 10 000 population)                                                 0
# Incidence of tuberculosis (per 100 000 population per year)                           0
# Infant mortality rate (between birth and 11 months per 1000 live births)              0
# Population using at least basic drinking-water services (%)                           0
# Population using safely managed sanitation services (%)                               0
# Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)    0
# Fertility rate total (births per woman)                                               0
# dtype: int64

# %% [markdown]
# Plot for Target (Life Expectancy) by Country

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(data=life_expect_df, x='Year', y='Life expectancy at birth (years)', hue='Country', marker='o', palette='rainbow')
plt.title("Life Expectancy Over Time (2000–2021)")
plt.ylabel("Life Expectancy")
plt.grid(True)
plt.show()

# %%
life_expect_df.nunique()
# Out:
# Country                                                                                10
# Year                                                                                   22
# Life expectancy at birth (years)                                                      150
# Hospital beds (per 10 000 population)                                                 161
# Incidence of tuberculosis (per 100 000 population per year)                           117
# Infant mortality rate (between birth and 11 months per 1000 live births)              154
# Population using at least basic drinking-water services (%)                            45
# Population using safely managed sanitation services (%)                                64
# Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)    189
# Fertility rate total (births per woman)                                                44
# dtype: int64

# %%
life_expect_df.describe()
# Out:
#               Year  Life expectancy at birth (years)  \
# count   220.000000                        220.000000
# mean   2010.500000                         73.963182
# std       6.358757                          7.116875
# min    2000.000000                         54.100000
# 25%    2005.000000                         70.200000
# 50%    2010.500000                         75.400000
# 75%    2016.000000                         78.825000
# max    2021.000000                         84.700000
#
#        Hospital beds (per 10 000 population)  \
# count                             220.000000
# mean                               52.475789
# std                                38.487227
# min                                 5.000000
# 25%                                23.500000
# 50%                                34.700000
# 75%                                71.025000
# max                               147.000000
#
#        Incidence of tuberculosis (per 100 000 population per year)  \
# count                                         220.000000
# mean                                           81.811818
# std                                            87.343244
# min                                             2.300000
# 25%                                            15.000000
# 50%                                            50.000000
# 75%                                            94.000000
# max                                           322.000000
#
#        Infant mortality rate (between birth and 11 months per 1000 live births)  \
# count                                         220.000000
# mean                                           19.073636
# std                                            23.474860
# min                                             1.800000
# 25%                                             4.700000
# 50%                                             7.750000
# 75%                                            20.175000
# max                                            97.100000
#
#        Population using at least basic drinking-water services (%)  \
# count                                         220.000000
# mean                                           91.787879
# std                                            11.950639
# min                                            44.000000
# 25%                                            91.590909
# 50%                                            96.000000
# 75%                                            99.000000
# max                                           100.000000
#
#        Population using safely managed sanitation services (%)  \
# count                                         220.000000
# mean                                           65.540909
# std                                            30.336517
# min                                             6.000000
# 25%                                            37.750000
# 50%                                            72.500000
# 75%                                            97.000000
# max                                            99.000000
#
#        Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)  \
# count                                         220.000000
# mean                                            7.063955
# std                                             3.714036
# min                                             2.490000
# 25%                                             4.245000
# 50%                                             5.615000
# 75%                                             8.960000
# max                                            18.810000
#
#        Fertility rate total (births per woman)
# count                               220.000000
# mean                                  2.247273
# std                                   1.291752
# min                                   0.800000
# 25%                                   1.500000
# 50%                                   1.800000
# 75%                                   2.425000
# max                                   6.100000

# %% [markdown]
# Heat Map for Numeric Columns

# %%
numeric_data = life_expect_df.select_dtypes(include=['float64', 'int64'])

# correlation between columns
sns.heatmap(numeric_data.corr(), annot=True, cmap='YlGnBu', fmt=".2f")
plt.title("Correlation Heatmap of Life Expectancy Data")
plt.show()

# %% [markdown]
# Plot for Fertility rate total

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(data=life_expect_df, x='Year', y='Fertility rate total (births per woman)', hue='Country', marker='o',palette='gist_rainbow')
plt.title("FRT (births per woman) Over Time (2000–2021)")
plt.ylabel("Fertility rate total (births per woman)")
plt.grid(True)
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

life_expect_df = life_expect_df.sort_values(['Country', 'Year']).reset_index(drop=True)

life_le = LabelEncoder()
life_expect_df['Country_enc'] = life_le.fit_transform(life_expect_df['Country'])
life_expect_df['Country_enc'].value_counts()
# Out:
# Country_enc
# 0    22
# 1    22
# 2    22
# 3    22
# 4    22
# 5    22
# 6    22
# 7    22
# 8    22
# 9    22
# Name: count, dtype: int64

# %%
life_expect_df
# Out:
#     Country  Year  Life expectancy at birth (years)  \
# 0    BRAZIL  2000                              71.5
# 1    BRAZIL  2001                              71.8
# 2    BRAZIL  2002                              72.0
# 3    BRAZIL  2003                              72.3
# 4    BRAZIL  2004                              72.5
# ..      ...   ...                               ...
# 215     USA  2017                              78.5
# 216     USA  2018                              78.6
# 217     USA  2019                              78.7
# 218     USA  2020                              76.9
# 219     USA  2021                              76.4
#
#      Hospital beds (per 10 000 population)  \
# 0                                27.800000
# 1                                27.500000
# 2                                25.600000
# 3                                24.000000
# 4                                52.475789
# ..                                     ...
# 215                              28.200000
# 216                              27.800000
# 217                              27.500000
# 218                              27.400000
# 219                              52.475789
#
#      Incidence of tuberculosis (per 100 000 population per year)  \
# 0                                                 51.0
# 1                                                 48.0
# 2                                                 52.0
# 3                                                 53.0
# 4                                                 54.0
# ..                                                 ...
# 215                                                3.0
# 216                                                2.9
# 217                                                2.9
# 218                                                2.3
# 219                                                2.6
#
#      Infant mortality rate (between birth and 11 months per 1000 live births)  \
# 0                                                 29.1
# 1                                                 27.3
# 2                                                 25.5
# 3                                                 23.9
# 4                                                 22.4
# ..                                                 ...
# 215                                                5.6
# 216                                                5.6
# 217                                                5.5
# 218                                                5.5
# 219                                                5.5
#
#      Population using at least basic drinking-water services (%)  \
# 0                                                 93.0
# 1                                                 94.0
# 2                                                 94.0
# 3                                                 94.0
# 4                                                 95.0
# ..                                                 ...
# 215                                              100.0
# 216                                              100.0
# 217                                              100.0
# 218                                              100.0
# 219                                              100.0
#
#      Population using safely managed sanitation services (%)  \
# 0                                                   36
# 1                                                   36
# 2                                                   37
# 3                                                   37
# 4                                                   37
# ..                                                 ...
# 215                                                 97
# 216                                                 97
# 217                                                 97
# 218                                                 97
# 219                                                 97
#
#      Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)  \
# 0                                                 8.33
# 1                                                 8.55
# 2                                                 8.70
# 3                                                 8.19
# 4                                                 8.12
# ..                                                 ...
# 215                                              16.75
# 216                                              16.62
# 217                                              16.66
# 218                                              18.81
# 219                                              17.51
#
#      Fertility rate total (births per woman)  Country_enc
# 0                                        2.2            0
# 1                                        2.2            0
# 2                                        2.1            0
# 3                                        2.0            0
# 4                                        2.0            0
# ..                                       ...          ...
# 215                                      1.8            9
# 216                                      1.7            9
# 217                                      1.7            9
# 218                                      1.6            9
# 219                                      1.7            9
#
# [220 rows x 11 columns]

# %%
# Define target and exclude identifier columns from features
target = 'Life expectancy at birth (years)'
exclude_cols = ['Country', 'Year', target]
features = [col for col in life_expect_df.columns if col not in exclude_cols]

# %%
look_back = 3  # Number of past years to use as features

life_X, life_y, year_list, country_list = [], [], [], []

for country in life_expect_df['Country'].unique():
    # Get data for this country and sort by year
    country_data = life_expect_df[life_expect_df['Country'] == country].sort_values('Year')
    features_data = country_data[features].values
    target_data = country_data[target].values
    years_data = country_data['Year'].values

    # Create samples using sliding window
    for i in range(len(country_data) - look_back):
        life_X.append(features_data[i:i+look_back])
        life_y.append(target_data[i+look_back])
        year_list.append(years_data[i+look_back])
        country_list.append(country)

# Convert to numpy arrays
life_X = np.array(life_X)
life_y = np.array(life_y)
year_list = np.array(year_list)
country_list = np.array(country_list)

# Split into train and test sets
train_idx = year_list <= 2018  # Train: up to 2018
test_idx = year_list > 2018    # Test: 2019, 2020, 2021

X_train, y_train = life_X[train_idx], life_y[train_idx]
X_test, y_test = life_X[test_idx], life_y[test_idx]
test_countries = country_list[test_idx]
test_years = year_list[test_idx]

# %%
print("Training Samples for Life Expectancy:", X_train.shape[0])
print("Testing Samples for Life Expectancy :", X_test.shape[0])
# Out:
# Training Samples for Life Expectancy: 160
# Testing Samples for Life Expectancy : 30

# %%
X_train
# Out:
# array([[[27.8       , 51.        , 29.1       , ...,  8.33      ,
#           2.2       ,  0.        ],
#         [27.5       , 48.        , 27.3       , ...,  8.55      ,
#           2.2       ,  0.        ],
#         [25.6       , 52.        , 25.5       , ...,  8.7       ,
#           2.1       ,  0.        ]],
#
#        [[27.5       , 48.        , 27.3       , ...,  8.55      ,
#           2.2       ,  0.        ],
#         [25.6       , 52.        , 25.5       , ...,  8.7       ,
#           2.1       ,  0.        ],
#         [24.        , 53.        , 23.9       , ...,  8.19      ,
#           2.        ,  0.        ]],
#
#        [[25.6       , 52.        , 25.5       , ...,  8.7       ,
#           2.1       ,  0.        ],
#         [24.        , 53.        , 23.9       , ...,  8.19      ,
#           2.        ,  0.        ],
#         [52.47578947, 54.        , 22.4       , ...,  8.12      ,
#           2.        ,  0.        ]],
#
#        ...,
#
#        [[28.6       ,  3.3       ,  5.9       , ..., 15.99      ,
#           1.9       ,  9.        ],
#         [28.        ,  3.2       ,  5.8       , ..., 16.19      ,
#           1.9       ,  9.        ],
#         [27.7       ,  3.2       ,  5.8       , ..., 16.48      ,
#           1.8       ,  9.        ]],
#
#        [[28.        ,  3.2       ,  5.8       , ..., 16.19      ,
#           1.9       ,  9.        ],
#         [27.7       ,  3.2       ,  5.8       , ..., 16.48      ,
#           1.8       ,  9.        ],
#         [27.3       ,  3.1       ,  5.7       , ..., 16.79      ,
#           1.8       ,  9.        ]],
#
#        [[27.7       ,  3.2       ,  5.8       , ..., 16.48      ,
#           1.8       ,  9.        ],
#         [27.3       ,  3.1       ,  5.7       , ..., 16.79      ,
#           1.8       ,  9.        ],
#         [28.2       ,  3.        ,  5.6       , ..., 16.75      ,
#           1.8       ,  9.        ]]])

# %%
X_test
# Out:
# array([[[ 23.2       ,  43.        ,  14.6       ,  98.        ,
#           45.        ,   9.17      ,   1.7       ,   0.        ],
#         [ 23.        ,  44.        ,  13.3       ,  98.        ,
#           46.        ,   9.47      ,   1.7       ,   0.        ],
#         [ 22.6       ,  46.        ,  13.1       ,  99.        ,
#           47.        ,   9.46      ,   1.7       ,   0.        ]],
#
#        [[ 23.        ,  44.        ,  13.3       ,  98.        ,
#           46.        ,   9.47      ,   1.7       ,   0.        ],
#         [ 22.6       ,  46.        ,  13.1       ,  99.        ,
#           47.        ,   9.46      ,   1.7       ,   0.        ],
#         [ 22.4       ,  46.        ,  13.        ,  99.        ,
#           48.        ,   9.61      ,   1.7       ,   0.        ]],
#
#        [[ 22.6       ,  46.        ,  13.1       ,  99.        ,
#           47.        ,   9.46      ,   1.7       ,   0.        ],
#         [ 22.4       ,  46.        ,  13.        ,  99.        ,
#           48.        ,   9.61      ,   1.7       ,   0.        ],
#         [ 24.3       ,  45.        ,  12.8       ,  99.        ,
#           49.        ,   9.62      ,   1.7       ,   0.        ]],
#
#        [[ 40.6       ,  63.        ,   7.6       ,  93.        ,
#           53.        ,   4.98      ,   1.8       ,   1.        ],
#         [ 43.4       ,  62.        ,   7.        ,  94.        ,
#           56.        ,   5.07      ,   1.8       ,   1.        ],
#         [ 46.        ,  61.        ,   6.4       ,  95.        ,
#           60.        ,   5.17      ,   1.5       ,   1.        ]],
#
#        [[ 43.4       ,  62.        ,   7.        ,  94.        ,
#           56.        ,   5.07      ,   1.8       ,   1.        ],
#         [ 46.        ,  61.        ,   6.4       ,  95.        ,
#           60.        ,   5.17      ,   1.5       ,   1.        ],
#         [ 48.3       ,  58.        ,   6.        ,  95.        ,
#           63.        ,   5.35      ,   1.5       ,   1.        ]],
#
#        [[ 46.        ,  61.        ,   6.4       ,  95.        ,
#           60.        ,   5.17      ,   1.5       ,   1.        ],
#         [ 48.3       ,  58.        ,   6.        ,  95.        ,
#           63.        ,   5.35      ,   1.5       ,   1.        ],
#         [ 50.        ,  58.        ,   5.5       ,  96.        ,
#           65.        ,   5.59      ,   1.2       ,   1.        ]],
#
#        [[ 16.8       , 225.        ,  34.7       ,  90.        ,
#           39.        ,   3.5       ,   2.3       ,   2.        ],
#         [ 16.7       , 217.        ,  33.        ,  90.        ,
#           41.        ,   2.94      ,   2.2       ,   2.        ],
#         [ 16.5       , 208.        ,  31.3       ,  91.        ,
#           44.        ,   2.86      ,   2.2       ,   2.        ]],
#
#        [[ 16.7       , 217.        ,  33.        ,  90.        ,
#           41.        ,   2.94      ,   2.2       ,   2.        ],
#         [ 16.5       , 208.        ,  31.3       ,  91.        ,
#           44.        ,   2.86      ,   2.2       ,   2.        ],
#         [ 16.3       , 202.        ,  29.7       ,  92.        ,
#           46.        ,   2.95      ,   2.1       ,   2.        ]],
#
#        [[ 16.5       , 208.        ,  31.3       ,  91.        ,
#           44.        ,   2.86      ,   2.2       ,   2.        ],
#         [ 16.3       , 202.        ,  29.7       ,  92.        ,
#           46.        ,   2.95      ,   2.1       ,   2.        ],
#         [ 16.2       , 195.        ,  28.2       ,  92.        ,
#           48.        ,   3.34      ,   2.        ,   2.        ]],
#
#        [[131.1       ,  16.        ,   2.        ,  99.        ,
#           99.        ,  10.66      ,   1.4       ,   3.        ],
#         [130.5       ,  15.        ,   1.9       ,  99.        ,
#           99.        ,  10.66      ,   1.4       ,   3.        ],
#         [130.        ,  14.        ,   1.9       ,  99.        ,
#           99.        ,  10.74      ,   1.4       ,   3.        ]],
#
#        [[130.5       ,  15.        ,   1.9       ,  99.        ,
#           99.        ,  10.66      ,   1.4       ,   3.        ],
#         [130.        ,  14.        ,   1.9       ,  99.        ,
#           99.        ,  10.74      ,   1.4       ,   3.        ],
#         [128.8       ,  13.        ,   1.8       ,  99.        ,
#           99.        ,  10.97      ,   1.4       ,   3.        ]],
#
#        [[130.        ,  14.        ,   1.9       ,  99.        ,
#           99.        ,  10.74      ,   1.4       ,   3.        ],
#         [128.8       ,  13.        ,   1.8       ,  99.        ,
#           99.        ,  10.97      ,   1.4       ,   3.        ],
#         [127.2       ,  12.        ,   1.8       ,  99.        ,
#           99.        ,  11.21      ,   1.3       ,   3.        ]],
#
#        [[ 52.47578947, 219.        ,  69.5       ,  70.        ,
#           28.        ,   3.65      ,   5.3       ,   4.        ],
#         [ 52.47578947, 219.        ,  68.6       ,  71.        ,
#           29.        ,   3.75      ,   5.2       ,   4.        ],
#         [ 52.47578947, 219.        ,  67.4       ,  73.        ,
#           29.        ,   3.09      ,   5.        ,   4.        ]],
#
#        [[ 52.47578947, 219.        ,  68.6       ,  71.        ,
#           29.        ,   3.75      ,   5.2       ,   4.        ],
#         [ 52.47578947, 219.        ,  67.4       ,  73.        ,
#           29.        ,   3.09      ,   5.        ,   4.        ],
#         [ 52.47578947, 219.        ,  66.1       ,  75.        ,
#           30.        ,   2.99      ,   4.9       ,   4.        ]],
#
#        [[ 52.47578947, 219.        ,  67.4       ,  73.        ,
#           29.        ,   3.09      ,   5.        ,   4.        ],
#         [ 52.47578947, 219.        ,  66.1       ,  75.        ,
#           30.        ,   2.99      ,   4.9       ,   4.        ],
#         [ 52.47578947, 219.        ,  64.7       ,  76.        ,
#           31.        ,   3.38      ,   4.7       ,   4.        ]],
#
#        [[119.7       ,  76.        ,   2.8       , 100.        ,
#           97.        ,   6.89      ,   1.2       ,   5.        ],
#         [122.5       ,  70.        ,   2.7       , 100.        ,
#           98.        ,   7.05      ,   1.1       ,   5.        ],
#         [124.2       ,  64.        ,   2.7       , 100.        ,
#           99.        ,   7.46      ,   1.        ,   5.        ]],
#
#        [[122.5       ,  70.        ,   2.7       , 100.        ,
#           98.        ,   7.05      ,   1.1       ,   5.        ],
#         [124.2       ,  64.        ,   2.7       , 100.        ,
#           99.        ,   7.46      ,   1.        ,   5.        ],
#         [124.2       ,  58.        ,   2.6       , 100.        ,
#           99.        ,   8.13      ,   0.9       ,   5.        ]],
#
#        [[124.2       ,  64.        ,   2.7       , 100.        ,
#           99.        ,   7.46      ,   1.        ,   5.        ],
#         [124.2       ,  58.        ,   2.6       , 100.        ,
#           99.        ,   8.13      ,   0.9       ,   5.        ],
#         [126.5       ,  48.        ,   2.5       , 100.        ,
#           99.        ,   8.36      ,   0.8       ,   5.        ]],
#
#        [[ 74.        ,  63.        ,   6.1       ,  97.        ,
#           60.        ,   5.29      ,   1.8       ,   6.        ],
#         [ 72.5       ,  59.        ,   5.6       ,  97.        ,
#           60.        ,   5.36      ,   1.6       ,   6.        ],
#         [ 71.7       ,  54.        ,   5.1       ,  97.        ,
#           60.        ,   5.36      ,   1.6       ,   6.        ]],
#
#        [[ 72.5       ,  59.        ,   5.6       ,  97.        ,
#           60.        ,   5.36      ,   1.6       ,   6.        ],
#         [ 71.7       ,  54.        ,   5.1       ,  97.        ,
#           60.        ,   5.36      ,   1.6       ,   6.        ],
#         [ 70.7       ,  50.        ,   4.7       ,  97.        ,
#           61.        ,   5.65      ,   1.5       ,   6.        ]],
#
#        [[ 71.7       ,  54.        ,   5.1       ,  97.        ,
#           60.        ,   5.36      ,   1.6       ,   6.        ],
#         [ 70.7       ,  50.        ,   4.7       ,  97.        ,
#           61.        ,   5.65      ,   1.5       ,   6.        ],
#         [ 70.8       ,  49.        ,   4.4       ,  97.        ,
#           61.        ,   8.04      ,   1.5       ,   6.        ]],
#
#        [[ 21.2       ,  10.        ,   6.9       ,  99.        ,
#           80.        ,   6.24      ,   2.7       ,   7.        ],
#         [ 21.3       ,  10.        ,   6.5       ,  99.        ,
#           80.        ,   6.03      ,   2.7       ,   7.        ],
#         [ 21.5       ,  11.        ,   6.1       ,  99.        ,
#           80.        ,   5.34      ,   2.7       ,   7.        ]],
#
#        [[ 21.3       ,  10.        ,   6.5       ,  99.        ,
#           80.        ,   6.03      ,   2.7       ,   7.        ],
#         [ 21.5       ,  11.        ,   6.1       ,  99.        ,
#           80.        ,   5.34      ,   2.7       ,   7.        ],
#         [ 21.5       ,  11.        ,   5.8       ,  99.        ,
#           80.        ,   5.47      ,   2.5       ,   7.        ]],
#
#        [[ 21.5       ,  11.        ,   6.1       ,  99.        ,
#           80.        ,   5.34      ,   2.7       ,   7.        ],
#         [ 21.5       ,  11.        ,   5.8       ,  99.        ,
#           80.        ,   5.47      ,   2.5       ,   7.        ],
#         [ 21.8       ,   8.7       ,   5.5       ,  99.        ,
#           80.        ,   6.65      ,   2.3       ,   7.        ]],
#
#        [[ 25.7       ,   9.9       ,   3.8       , 100.        ,
#           98.        ,   9.77      ,   1.8       ,   8.        ],
#         [ 25.4       ,   8.9       ,   3.8       , 100.        ,
#           98.        ,   9.6       ,   1.7       ,   8.        ],
#         [ 25.        ,   8.        ,   3.8       , 100.        ,
#           98.        ,   9.74      ,   1.7       ,   8.        ]],
#
#        [[ 25.4       ,   8.9       ,   3.8       , 100.        ,
#           98.        ,   9.6       ,   1.7       ,   8.        ],
#         [ 25.        ,   8.        ,   3.8       , 100.        ,
#           98.        ,   9.74      ,   1.7       ,   8.        ],
#         [ 24.5       ,   8.1       ,   3.8       , 100.        ,
#           98.        ,   9.95      ,   1.6       ,   8.        ]],
#
#        [[ 25.        ,   8.        ,   3.8       , 100.        ,
#           98.        ,   9.74      ,   1.7       ,   8.        ],
#         [ 24.5       ,   8.1       ,   3.8       , 100.        ,
#           98.        ,   9.95      ,   1.6       ,   8.        ],
#         [ 24.3       ,   7.        ,   3.9       , 100.        ,
#           98.        ,  11.97      ,   1.6       ,   8.        ]],
#
#        [[ 27.3       ,   3.1       ,   5.7       , 100.        ,
#           97.        ,  16.79      ,   1.8       ,   9.        ],
#         [ 28.2       ,   3.        ,   5.6       , 100.        ,
#           97.        ,  16.75      ,   1.8       ,   9.        ],
#         [ 27.8       ,   2.9       ,   5.6       , 100.        ,
#           97.        ,  16.62      ,   1.7       ,   9.        ]],
#
#        [[ 28.2       ,   3.        ,   5.6       , 100.        ,
#           97.        ,  16.75      ,   1.8       ,   9.        ],
#         [ 27.8       ,   2.9       ,   5.6       , 100.        ,
#           97.        ,  16.62      ,   1.7       ,   9.        ],
#         [ 27.5       ,   2.9       ,   5.5       , 100.        ,
#           97.        ,  16.66      ,   1.7       ,   9.        ]],
#
#        [[ 27.8       ,   2.9       ,   5.6       , 100.        ,
#           97.        ,  16.62      ,   1.7       ,   9.        ],
#         [ 27.5       ,   2.9       ,   5.5       , 100.        ,
#           97.        ,  16.66      ,   1.7       ,   9.        ],
#         [ 27.4       ,   2.3       ,   5.5       , 100.        ,
#           97.        ,  18.81      ,   1.6       ,   9.        ]]])

# %%
# Display each test sample's year, country, and its corresponding input features
for i in range(len(X_test)):
    print(f"Sample {i + 1}:")
    print(f"  Country: {test_countries[i]}")
    print(f"  Year: {test_years[i]}")
    print(f"  Input features (look_back={look_back}):")

    for t in range(look_back):
        print(f"    Time step {t + 1}: {X_test[i][t]}")

    print("-" * 60)
# Out:
# Sample 1:
#   Country: BRAZIL
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [23.2  43.   14.6  98.   45.    9.17  1.7   0.  ]
#     Time step 2: [23.   44.   13.3  98.   46.    9.47  1.7   0.  ]
#     Time step 3: [22.6  46.   13.1  99.   47.    9.46  1.7   0.  ]
# ------------------------------------------------------------
# Sample 2:
#   Country: BRAZIL
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [23.   44.   13.3  98.   46.    9.47  1.7   0.  ]
#     Time step 2: [22.6  46.   13.1  99.   47.    9.46  1.7   0.  ]
#     Time step 3: [22.4  46.   13.   99.   48.    9.61  1.7   0.  ]
# ------------------------------------------------------------
# Sample 3:
#   Country: BRAZIL
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [22.6  46.   13.1  99.   47.    9.46  1.7   0.  ]
#     Time step 2: [22.4  46.   13.   99.   48.    9.61  1.7   0.  ]
#     Time step 3: [24.3  45.   12.8  99.   49.    9.62  1.7   0.  ]
# ------------------------------------------------------------
# Sample 4:
#   Country: CHINA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [40.6  63.    7.6  93.   53.    4.98  1.8   1.  ]
#     Time step 2: [43.4  62.    7.   94.   56.    5.07  1.8   1.  ]
#     Time step 3: [46.   61.    6.4  95.   60.    5.17  1.5   1.  ]
# ------------------------------------------------------------
# Sample 5:
#   Country: CHINA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [43.4  62.    7.   94.   56.    5.07  1.8   1.  ]
#     Time step 2: [46.   61.    6.4  95.   60.    5.17  1.5   1.  ]
#     Time step 3: [48.3  58.    6.   95.   63.    5.35  1.5   1.  ]
# ------------------------------------------------------------
# Sample 6:
#   Country: CHINA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [46.   61.    6.4  95.   60.    5.17  1.5   1.  ]
#     Time step 2: [48.3  58.    6.   95.   63.    5.35  1.5   1.  ]
#     Time step 3: [50.   58.    5.5  96.   65.    5.59  1.2   1.  ]
# ------------------------------------------------------------
# Sample 7:
#   Country: INDIA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [ 16.8 225.   34.7  90.   39.    3.5   2.3   2. ]
#     Time step 2: [ 16.7  217.    33.    90.    41.     2.94   2.2    2.  ]
#     Time step 3: [ 16.5  208.    31.3   91.    44.     2.86   2.2    2.  ]
# ------------------------------------------------------------
# Sample 8:
#   Country: INDIA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [ 16.7  217.    33.    90.    41.     2.94   2.2    2.  ]
#     Time step 2: [ 16.5  208.    31.3   91.    44.     2.86   2.2    2.  ]
#     Time step 3: [ 16.3  202.    29.7   92.    46.     2.95   2.1    2.  ]
# ------------------------------------------------------------
# Sample 9:
#   Country: INDIA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [ 16.5  208.    31.3   91.    44.     2.86   2.2    2.  ]
#     Time step 2: [ 16.3  202.    29.7   92.    46.     2.95   2.1    2.  ]
#     Time step 3: [ 16.2  195.    28.2   92.    48.     3.34   2.     2.  ]
# ------------------------------------------------------------
# Sample 10:
#   Country: JAPAN
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [131.1   16.     2.    99.    99.    10.66   1.4    3.  ]
#     Time step 2: [130.5   15.     1.9   99.    99.    10.66   1.4    3.  ]
#     Time step 3: [130.    14.     1.9   99.    99.    10.74   1.4    3.  ]
# ------------------------------------------------------------
# Sample 11:
#   Country: JAPAN
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [130.5   15.     1.9   99.    99.    10.66   1.4    3.  ]
#     Time step 2: [130.    14.     1.9   99.    99.    10.74   1.4    3.  ]
#     Time step 3: [128.8   13.     1.8   99.    99.    10.97   1.4    3.  ]
# ------------------------------------------------------------
# Sample 12:
#   Country: JAPAN
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [130.    14.     1.9   99.    99.    10.74   1.4    3.  ]
#     Time step 2: [128.8   13.     1.8   99.    99.    10.97   1.4    3.  ]
#     Time step 3: [127.2   12.     1.8   99.    99.    11.21   1.3    3.  ]
# ------------------------------------------------------------
# Sample 13:
#   Country: NIGERIA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [ 52.47578947 219.          69.5         70.          28.
#    3.65         5.3          4.        ]
#     Time step 2: [ 52.47578947 219.          68.6         71.          29.
#    3.75         5.2          4.        ]
#     Time step 3: [ 52.47578947 219.          67.4         73.          29.
#    3.09         5.           4.        ]
# ------------------------------------------------------------
# Sample 14:
#   Country: NIGERIA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [ 52.47578947 219.          68.6         71.          29.
#    3.75         5.2          4.        ]
#     Time step 2: [ 52.47578947 219.          67.4         73.          29.
#    3.09         5.           4.        ]
#     Time step 3: [ 52.47578947 219.          66.1         75.          30.
#    2.99         4.9          4.        ]
# ------------------------------------------------------------
# Sample 15:
#   Country: NIGERIA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [ 52.47578947 219.          67.4         73.          29.
#    3.09         5.           4.        ]
#     Time step 2: [ 52.47578947 219.          66.1         75.          30.
#    2.99         4.9          4.        ]
#     Time step 3: [ 52.47578947 219.          64.7         76.          31.
#    3.38         4.7          4.        ]
# ------------------------------------------------------------
# Sample 16:
#   Country: REPUBLIC OF KOREA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [119.7   76.     2.8  100.    97.     6.89   1.2    5.  ]
#     Time step 2: [122.5   70.     2.7  100.    98.     7.05   1.1    5.  ]
#     Time step 3: [124.2   64.     2.7  100.    99.     7.46   1.     5.  ]
# ------------------------------------------------------------
# Sample 17:
#   Country: REPUBLIC OF KOREA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [122.5   70.     2.7  100.    98.     7.05   1.1    5.  ]
#     Time step 2: [124.2   64.     2.7  100.    99.     7.46   1.     5.  ]
#     Time step 3: [124.2   58.     2.6  100.    99.     8.13   0.9    5.  ]
# ------------------------------------------------------------
# Sample 18:
#   Country: REPUBLIC OF KOREA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [124.2   64.     2.7  100.    99.     7.46   1.     5.  ]
#     Time step 2: [124.2   58.     2.6  100.    99.     8.13   0.9    5.  ]
#     Time step 3: [126.5   48.     2.5  100.    99.     8.36   0.8    5.  ]
# ------------------------------------------------------------
# Sample 19:
#   Country: RUSSIA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [74.   63.    6.1  97.   60.    5.29  1.8   6.  ]
#     Time step 2: [72.5  59.    5.6  97.   60.    5.36  1.6   6.  ]
#     Time step 3: [71.7  54.    5.1  97.   60.    5.36  1.6   6.  ]
# ------------------------------------------------------------
# Sample 20:
#   Country: RUSSIA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [72.5  59.    5.6  97.   60.    5.36  1.6   6.  ]
#     Time step 2: [71.7  54.    5.1  97.   60.    5.36  1.6   6.  ]
#     Time step 3: [70.7  50.    4.7  97.   61.    5.65  1.5   6.  ]
# ------------------------------------------------------------
# Sample 21:
#   Country: RUSSIA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [71.7  54.    5.1  97.   60.    5.36  1.6   6.  ]
#     Time step 2: [70.7  50.    4.7  97.   61.    5.65  1.5   6.  ]
#     Time step 3: [70.8  49.    4.4  97.   61.    8.04  1.5   6.  ]
# ------------------------------------------------------------
# Sample 22:
#   Country: SAUDI ARABIA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [21.2  10.    6.9  99.   80.    6.24  2.7   7.  ]
#     Time step 2: [21.3  10.    6.5  99.   80.    6.03  2.7   7.  ]
#     Time step 3: [21.5  11.    6.1  99.   80.    5.34  2.7   7.  ]
# ------------------------------------------------------------
# Sample 23:
#   Country: SAUDI ARABIA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [21.3  10.    6.5  99.   80.    6.03  2.7   7.  ]
#     Time step 2: [21.5  11.    6.1  99.   80.    5.34  2.7   7.  ]
#     Time step 3: [21.5  11.    5.8  99.   80.    5.47  2.5   7.  ]
# ------------------------------------------------------------
# Sample 24:
#   Country: SAUDI ARABIA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [21.5  11.    6.1  99.   80.    5.34  2.7   7.  ]
#     Time step 2: [21.5  11.    5.8  99.   80.    5.47  2.5   7.  ]
#     Time step 3: [21.8   8.7   5.5  99.   80.    6.65  2.3   7.  ]
# ------------------------------------------------------------
# Sample 25:
#   Country: UK
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [ 25.7    9.9    3.8  100.    98.     9.77   1.8    8.  ]
#     Time step 2: [ 25.4   8.9   3.8 100.   98.    9.6   1.7   8. ]
#     Time step 3: [ 25.     8.     3.8  100.    98.     9.74   1.7    8.  ]
# ------------------------------------------------------------
# Sample 26:
#   Country: UK
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [ 25.4   8.9   3.8 100.   98.    9.6   1.7   8. ]
#     Time step 2: [ 25.     8.     3.8  100.    98.     9.74   1.7    8.  ]
#     Time step 3: [ 24.5    8.1    3.8  100.    98.     9.95   1.6    8.  ]
# ------------------------------------------------------------
# Sample 27:
#   Country: UK
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [ 25.     8.     3.8  100.    98.     9.74   1.7    8.  ]
#     Time step 2: [ 24.5    8.1    3.8  100.    98.     9.95   1.6    8.  ]
#     Time step 3: [ 24.3    7.     3.9  100.    98.    11.97   1.6    8.  ]
# ------------------------------------------------------------
# Sample 28:
#   Country: USA
#   Year: 2019
#   Input features (look_back=3):
#     Time step 1: [ 27.3    3.1    5.7  100.    97.    16.79   1.8    9.  ]
#     Time step 2: [ 28.2    3.     5.6  100.    97.    16.75   1.8    9.  ]
#     Time step 3: [ 27.8    2.9    5.6  100.    97.    16.62   1.7    9.  ]
# ------------------------------------------------------------
# Sample 29:
#   Country: USA
#   Year: 2020
#   Input features (look_back=3):
#     Time step 1: [ 28.2    3.     5.6  100.    97.    16.75   1.8    9.  ]
#     Time step 2: [ 27.8    2.9    5.6  100.    97.    16.62   1.7    9.  ]
#     Time step 3: [ 27.5    2.9    5.5  100.    97.    16.66   1.7    9.  ]
# ------------------------------------------------------------
# Sample 30:
#   Country: USA
#   Year: 2021
#   Input features (look_back=3):
#     Time step 1: [ 27.8    2.9    5.6  100.    97.    16.62   1.7    9.  ]
#     Time step 2: [ 27.5    2.9    5.5  100.    97.    16.66   1.7    9.  ]
#     Time step 3: [ 27.4    2.3    5.5  100.    97.    18.81   1.6    9.  ]
# ------------------------------------------------------------

# %% [markdown]
# ### LSTM Regression Model

# %%
import numpy as np
import tensorflow as tf
import random
import os
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Setting the seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)


life_model = Sequential()
life_model.add(LSTM(50, activation='selu', input_shape=(look_back, len(features))))

life_model.add(Dense(1, activation='selu'))
life_model.compile(optimizer='adam', loss='mse')

life_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test), shuffle=False)
y_pred = life_model.predict(X_test)

# Regression Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nLife Expectancy in LSTM R²: {r2:.4f}")
print(f"Life Expectancy in LSTM MAE: {mae:.4f}")
print(f"Life Expectancy in LSTM MSE: {mse:.4f}")
print(f"Life Expectancy in LSTM RMSE: {rmse:.4f}")
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 3607.6765 - val_loss: 1580.6964
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1592.4509 - val_loss: 146.9234
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 246.2841 - val_loss: 17.6335
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 115.5588 - val_loss: 13.3240
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.5791 - val_loss: 45.2004
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.2545 - val_loss: 21.4549
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.3830 - val_loss: 30.9427
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6614 - val_loss: 38.4292
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.2726 - val_loss: 20.8567
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.0906 - val_loss: 69.2096
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.5693 - val_loss: 28.1424
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.5400 - val_loss: 27.8903
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.6809 - val_loss: 14.8483
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3657 - val_loss: 8.1551
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2244 - val_loss: 13.9338
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4385 - val_loss: 7.2396
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0836 - val_loss: 10.5097
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6449 - val_loss: 8.7597
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8565 - val_loss: 6.9762
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8512 - val_loss: 9.9144
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6677 - val_loss: 6.4751
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0510 - val_loss: 7.8069
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9281 - val_loss: 8.9376
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9261 - val_loss: 5.7389
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9534 - val_loss: 8.5334
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8459 - val_loss: 8.3188
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6666 - val_loss: 5.5119
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8863 - val_loss: 9.2167
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9603 - val_loss: 9.3560
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3767 - val_loss: 5.2303
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4264 - val_loss: 10.2750
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5790 - val_loss: 13.8132
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5497 - val_loss: 5.1409
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2342 - val_loss: 15.4100
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5328 - val_loss: 22.6110
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2903 - val_loss: 7.1126
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.2056 - val_loss: 30.4831
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.4786 - val_loss: 30.8540
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.5349 - val_loss: 12.8414
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.9521 - val_loss: 70.8063
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.9505 - val_loss: 58.5693
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 88.3609 - val_loss: 32.8388
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.0655 - val_loss: 55.8057
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.4991 - val_loss: 85.5098
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 125.4778 - val_loss: 28.7284
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.4010 - val_loss: 8.5999
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4166 - val_loss: 13.2146
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.9066 - val_loss: 10.0850
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.2762 - val_loss: 8.0598
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8103 - val_loss: 5.2557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#
# Life Expectancy in LSTM R²: 0.8681
# Life Expectancy in LSTM MAE: 1.8062
# Life Expectancy in LSTM MSE: 5.2557
# Life Expectancy in LSTM RMSE: 2.2925

# %%
# Convert predictions to 1D array for easier display
y_pred_flat = y_pred.flatten()
y_test_flat = y_test.flatten()

print("\nFirst 10 Actual vs Predicted Life Expectancy:")
for actual, predicted in list(zip(y_test_flat, y_pred_flat))[:10]:
    print(f"Actual: {actual:.2f}, Predicted: {predicted:.2f}")
# Out:
# First 10 Actual vs Predicted Life Expectancy:
# Actual: 75.50, Predicted: 75.89
# Actual: 74.10, Predicted: 76.33
# Actual: 72.40, Predicted: 76.64
# Actual: 77.30, Predicted: 76.88
# Actual: 77.50, Predicted: 76.40
# Actual: 77.60, Predicted: 76.19
# Actual: 70.70, Predicted: 70.01
# Actual: 70.20, Predicted: 71.49
# Actual: 67.30, Predicted: 73.60
# Actual: 84.50, Predicted: 81.50

# %% [markdown]
# Plot actual vs predicted values

# %%
# Scatter Plot: Actuals & Predictions
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, color='royalblue', alpha=0.7, label="Actual")
plt.scatter(y_test, y_pred, color='red', alpha=0.7, label="Predicted")
plt.xlabel("Actual Life Expectancy (years)")
plt.ylabel("Predicted Life Expectancy (years)")
plt.title("LSTM Scatter Plot: Actual vs Predicted Life Expectancy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
print("\nLife Expectancy Inputs (2018-2020) used for the Prediction of 2021\n")

for country in life_expect_df['Country'].unique():

    country_data = life_expect_df[life_expect_df['Country'] == country].sort_values('Year')

    # Printing Country wise life expectancy for the years 2018, 2019, 2020
    print(f"--- {country} ---")
    for year in [2018, 2019, 2020]:
        value = country_data[country_data['Year'] == year]['Life expectancy at birth (years)']
        if not value.empty:
            print(f"Year: {year}, Life Expectancy: {value.values[0]:.2f}")

    # Actual 2021 life expectancy
    actual_2021 = country_data[country_data['Year'] == 2021]['Life expectancy at birth (years)']
    if not actual_2021.empty:
        print(f"Actual 2021 Life Expectancy: {actual_2021.values[0]:.2f}")
    else:
        print("Actual 2021 not available")

    # Predicted 2021 life expectancy from model
    idx = np.where((test_years == 2021) & (test_countries == country))[0]
    if len(idx) > 0:
        print(f"Predicted 2021 Life Expectancy: {y_pred[idx[0]][0]:.2f}")
    else:
        print("Prediction not available")
    print()
# Out:
# Life Expectancy Inputs (2018-2020) used for the Prediction of 2021
#
# --- BRAZIL ---
# Year: 2018, Life Expectancy: 75.30
# Year: 2019, Life Expectancy: 75.50
# Year: 2020, Life Expectancy: 74.10
# Actual 2021 Life Expectancy: 72.40
# Predicted 2021 Life Expectancy: 76.64
#
# --- CHINA ---
# Year: 2018, Life Expectancy: 77.10
# Year: 2019, Life Expectancy: 77.30
# Year: 2020, Life Expectancy: 77.50
# Actual 2021 Life Expectancy: 77.60
# Predicted 2021 Life Expectancy: 76.19
#
# --- INDIA ---
# Year: 2018, Life Expectancy: 70.40
# Year: 2019, Life Expectancy: 70.70
# Year: 2020, Life Expectancy: 70.20
# Actual 2021 Life Expectancy: 67.30
# Predicted 2021 Life Expectancy: 73.60
#
# --- JAPAN ---
# Year: 2018, Life Expectancy: 84.40
# Year: 2019, Life Expectancy: 84.50
# Year: 2020, Life Expectancy: 84.70
# Actual 2021 Life Expectancy: 84.50
# Predicted 2021 Life Expectancy: 80.95
#
# --- NIGERIA ---
# Year: 2018, Life Expectancy: 62.70
# Year: 2019, Life Expectancy: 63.10
# Year: 2020, Life Expectancy: 62.80
# Actual 2021 Life Expectancy: 63.40
# Predicted 2021 Life Expectancy: 66.20
#
# --- REPUBLIC OF KOREA ---
# Year: 2018, Life Expectancy: 83.20
# Year: 2019, Life Expectancy: 83.70
# Year: 2020, Life Expectancy: 83.80
# Actual 2021 Life Expectancy: 83.80
# Predicted 2021 Life Expectancy: 81.98
#
# --- RUSSIA ---
# Year: 2018, Life Expectancy: 72.70
# Year: 2019, Life Expectancy: 73.20
# Year: 2020, Life Expectancy: 71.40
# Actual 2021 Life Expectancy: 70.00
# Predicted 2021 Life Expectancy: 70.07
#
# --- SAUDI ARABIA ---
# Year: 2018, Life Expectancy: 76.80
# Year: 2019, Life Expectancy: 76.90
# Year: 2020, Life Expectancy: 76.10
# Actual 2021 Life Expectancy: 76.40
# Predicted 2021 Life Expectancy: 76.30
#
# --- UK ---
# Year: 2018, Life Expectancy: 80.60
# Year: 2019, Life Expectancy: 81.20
# Year: 2020, Life Expectancy: 80.10
# Actual 2021 Life Expectancy: 80.10
# Predicted 2021 Life Expectancy: 78.72
#
# --- USA ---
# Year: 2018, Life Expectancy: 78.60
# Year: 2019, Life Expectancy: 78.70
# Year: 2020, Life Expectancy: 76.90
# Actual 2021 Life Expectancy: 76.40
# Predicted 2021 Life Expectancy: 79.75

# %% [markdown]
# ### GRU Regression Model

# %%
from tensorflow.keras.layers import GRU

life_model = Sequential()
life_model.add(GRU(50, activation='selu', input_shape=(look_back, len(features))))

life_model.add(Dense(1, activation='selu'))
life_model.compile(optimizer='adam', loss='mse')

life_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test), shuffle=False)
y_pred = life_model.predict(X_test)

# Regression Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nLife Expectancy in GRU R²: {r2:.4f}")
print(f"Life Expectancy in GRU MAE: {mae:.4f}")
print(f"Life Expectancy in GRU MSE: {mse:.4f}")
print(f"Life Expectancy in GRU RMSE: {rmse:.4f}")
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2743.7837 - val_loss: 1073.1307
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 997.4651 - val_loss: 123.3436
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 204.0872 - val_loss: 56.3836
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 132.5773 - val_loss: 49.2676
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 101.7245 - val_loss: 32.7581
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 50.9182 - val_loss: 21.5643
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.6419 - val_loss: 102.8861
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.9771 - val_loss: 42.6179
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.6087 - val_loss: 20.9966
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.1161 - val_loss: 10.1337
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.1673 - val_loss: 25.4755
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.6455 - val_loss: 22.6849
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.2720 - val_loss: 23.9295
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.9880 - val_loss: 15.2397
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5248 - val_loss: 11.8256
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9059 - val_loss: 14.9013
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4742 - val_loss: 7.7559
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7865 - val_loss: 21.8596
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.9304 - val_loss: 18.5131
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.1385 - val_loss: 19.3597
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.1026 - val_loss: 12.8381
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2699 - val_loss: 7.7641
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8672 - val_loss: 16.5190
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7723 - val_loss: 14.5230
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9887 - val_loss: 10.9565
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7379 - val_loss: 11.5261
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5438 - val_loss: 8.9863
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6801 - val_loss: 12.8031
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5050 - val_loss: 14.5183
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0463 - val_loss: 7.2856
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7949 - val_loss: 13.6520
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1312 - val_loss: 12.9793
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8214 - val_loss: 6.2675
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6635 - val_loss: 13.3853
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6050 - val_loss: 11.3237
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6180 - val_loss: 6.2821
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9882 - val_loss: 13.3982
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7278 - val_loss: 12.0301
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6559 - val_loss: 6.0773
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4716 - val_loss: 14.8087
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6901 - val_loss: 13.6018
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8852 - val_loss: 5.8256
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3827 - val_loss: 17.6942
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7846 - val_loss: 16.1501
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5972 - val_loss: 5.8459
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3777 - val_loss: 20.8095
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9055 - val_loss: 20.4059
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.0721 - val_loss: 6.4613
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.3581 - val_loss: 31.5192
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.1759 - val_loss: 27.4235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
#
# Life Expectancy in GRU R²: 0.3116
# Life Expectancy in GRU MAE: 3.9997
# Life Expectancy in GRU MSE: 27.4235
# Life Expectancy in GRU RMSE: 5.2367

# %% [markdown]
# Plot actual vs predicted values

# %%
# Scatter Plot: Actuals & Predictions
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, color='royalblue', alpha=0.7, label="Actual")
plt.scatter(y_test, y_pred, color='red', alpha=0.7, label="Predicted")
plt.xlabel("Actual Life Expectancy (years)")
plt.ylabel("Predicted Life Expectancy (years)")
plt.title("GRU Scatter Plot: Actual vs Predicted Life Expectancy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Transformer Regression Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LayerNormalization
from tensorflow.keras.layers import MultiHeadAttention, Dropout, Flatten, Add
from tensorflow.keras.optimizers import Adam

num_heads = 3
embed_dim = len(features)
ff_dim = 64  # Feed-forward layer dimension


life_inputs = Input(shape=(look_back, len(features))) # Input layer

# Attention layers
life_atten_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(life_inputs, life_inputs)
life_atten_output = Dropout(0.1)(life_atten_output)
life_atten_output = Add()([life_inputs, life_atten_output])  # Residual connection
life_atten_output = LayerNormalization(epsilon=1e-6)(life_atten_output)

# Feed Forward Network
life_ff_output = Dense(ff_dim, activation='selu')(life_atten_output)
life_ff_output = Dense(embed_dim, activation='selu')(life_ff_output)
life_ff_output = Add()([life_atten_output, life_ff_output])  # Residual connection
life_ff_output = LayerNormalization(epsilon=1e-6)(life_ff_output)

flatten = Flatten()(life_ff_output)
life_outputs = Dense(1, activation='selu')(flatten) # Output layer

# Transformer Model
transformer_model = Model(inputs=life_inputs, outputs=life_outputs)
transformer_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Evaluation
transformer_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test), shuffle=False)
y_pred = transformer_model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nLife Expectancy in Transformer R²: {r2:.4f}")
print(f"Life Expectancy in Transformer MAE: {mae:.4f}")
print(f"Life Expectancy in Transformer MSE: {mse:.4f}")
print(f"Life Expectancy in Transformer RMSE: {rmse:.4f}")
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 5322.9775 - val_loss: 5325.6636
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4944.0669 - val_loss: 5190.2412
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4819.5947 - val_loss: 5083.2646
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4711.6577 - val_loss: 4972.5513
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4602.4453 - val_loss: 4854.3140
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4488.7300 - val_loss: 4727.9927
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4364.8970 - val_loss: 4593.7251
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4231.0791 - val_loss: 4451.5669
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4097.9419 - val_loss: 4301.9282
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3949.4402 - val_loss: 4144.9585
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3795.3899 - val_loss: 3981.2773
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3636.5249 - val_loss: 3811.5676
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3472.6809 - val_loss: 3637.1255
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3302.0171 - val_loss: 3458.9482
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3135.1777 - val_loss: 3278.2102
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2958.0361 - val_loss: 3095.5349
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2783.5901 - val_loss: 2912.5198
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2608.3916 - val_loss: 2730.0063
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2436.8284 - val_loss: 2549.4758
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2264.8525 - val_loss: 2371.8750
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2096.8501 - val_loss: 2197.8943
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1932.1610 - val_loss: 2028.5486
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1774.1847 - val_loss: 1864.8699
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1621.5940 - val_loss: 1707.3677
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1473.9108 - val_loss: 1556.9023
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1335.4418 - val_loss: 1413.6399
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1203.2883 - val_loss: 1278.3148
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1078.8093 - val_loss: 1151.1007
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 963.5162 - val_loss: 1032.2351
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 855.1165 - val_loss: 921.8928
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 756.6534 - val_loss: 820.0869
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 665.3455 - val_loss: 726.6504
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 582.0087 - val_loss: 641.3924
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 507.4254 - val_loss: 564.2718
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 440.0624 - val_loss: 494.8047
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 380.1539 - val_loss: 432.6607
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 326.8073 - val_loss: 377.4784
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 280.5540 - val_loss: 328.8065
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 240.2269 - val_loss: 285.9779
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 205.4353 - val_loss: 248.6789
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 175.4429 - val_loss: 216.3654
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 150.1697 - val_loss: 188.4963
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 128.5307 - val_loss: 164.6595
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 110.5583 - val_loss: 144.3763
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 95.7206 - val_loss: 127.1907
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 83.5553 - val_loss: 112.7177
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 73.6097 - val_loss: 100.5740
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.6048 - val_loss: 90.4326
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.3198 - val_loss: 81.9707
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.1313 - val_loss: 74.9206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#
# Life Expectancy in Transformer R²: -0.8807
# Life Expectancy in Transformer MAE: 7.4539
# Life Expectancy in Transformer MSE: 74.9206
# Life Expectancy in Transformer RMSE: 8.6557

# %% [markdown]
# Plot actual vs predicted values

# %%
# Scatter Plot: Actuals & Predictions
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, color='royalblue', alpha=0.7, label="Actual")
plt.scatter(y_test, y_pred, color='red', alpha=0.7, label="Predicted")
plt.xlabel("Actual Life Expectancy (years)")
plt.ylabel("Predicted Life Expectancy (years)")
plt.title("Transformer Scatter Plot: Actual vs Predicted Life Expectancy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gradient Boosting Regression Model

# %%
from sklearn.model_selection import GridSearchCV as life_cv_grid
from sklearn.ensemble import GradientBoostingRegressor as life_gb_regressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

reg_params_life = {
          'loss': ['squared_error','absolute_error','quantile','huber'],
          'learning_rate': [0.1, 0.001, 0.0001, 0.3],
          'n_estimators': [30, 60, 100],
          'criterion': ['friedman_mse','squared_error']
}

life_ml_mod = life_gb_regressor(random_state=41)

# Reshape X_train and X_test for Gradient Boosting
X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
X_test_reshaped = X_test.reshape(X_test.shape[0], -1)


life_ml_mod = life_cv_grid(life_ml_mod, reg_params_life, cv=2)
life_ml_mod.fit(X_train_reshaped, y_train)
print("Selected Regression Parameters GBR:\n", life_ml_mod.best_params_)

life_ml_mod = life_ml_mod.best_estimator_
life_ml_mod.fit(X_train_reshaped, y_train)

y_pred = life_ml_mod.predict(X_test_reshaped)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nLife Expectancy in GBR R²: {r2:.4f}")
print(f"Life Expectancy in GBR MAE : {mae:.4f}")
print(f"Life Expectancy in GBR MSE : {mse:.4f}")
print(f"Life Expectancy in GBR RMSE: {rmse:.4f}")
# Out:
# Selected Regression Parameters GBR:
#  {'criterion': 'squared_error', 'learning_rate': 0.1, 'loss': 'squared_error', 'n_estimators': 30}
#
# Life Expectancy in GBR R²: 0.9407
# Life Expectancy in GBR MAE : 1.2267
# Life Expectancy in GBR MSE : 2.3638
# Life Expectancy in GBR RMSE: 1.5375

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor as life_rf_regressor

reg_params_life = {
          'min_samples_split': [1, 2, 3, 6],
          'max_depth': [3, 6, 10],
          'n_estimators': [30, 60, 100],
          'criterion': ['friedman_mse','squared_error','absolute_error','poisson']
}

life_ml_mod = life_rf_regressor(random_state=41)
life_ml_mod = life_cv_grid(life_ml_mod, reg_params_life, cv=2)
life_ml_mod.fit(X_train_reshaped, y_train)
print("Selected Regression Parameters RFR:\n", life_ml_mod.best_params_)

life_ml_mod = life_ml_mod.best_estimator_
life_ml_mod.fit(X_train_reshaped, y_train)

y_pred = life_ml_mod.predict(X_test_reshaped)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nLife Expectancy in RFR R²: {r2:.4f}")
print(f"Life Expectancy in RFR MAE : {mae:.4f}")
print(f"Life Expectancy in RFR MSE : {mse:.4f}")
print(f"Life Expectancy in RFR RMSE: {rmse:.4f}")
# Out:
# Selected Regression Parameters RFR:
#  {'criterion': 'friedman_mse', 'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 30}
#
# Life Expectancy in RFR R²: 0.9227
# Life Expectancy in RFR MAE : 1.4286
# Life Expectancy in RFR MSE : 3.0787
# Life Expectancy in RFR RMSE: 1.7546

# %% [markdown]
# ### Linear Regression Regressor

# %%
from sklearn.linear_model import LinearRegression as life_line_regressor

reg_params_life = {
          'fit_intercept': [True, False],
          'copy_X': [True, False],
          'n_jobs': [3, 6, 10]
}

life_ml_mod = life_line_regressor()
life_ml_mod = life_cv_grid(life_ml_mod, reg_params_life, cv=2)
life_ml_mod.fit(X_train_reshaped, y_train)
print("Selected Regression Parameters LRR:\n", life_ml_mod.best_params_)

life_ml_mod = life_ml_mod.best_estimator_
life_ml_mod.fit(X_train_reshaped, y_train)

y_pred = life_ml_mod.predict(X_test_reshaped)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nLife Expectancy in LRR R²: {r2:.4f}")
print(f"Life Expectancy in LRR MAE : {mae:.4f}")
print(f"Life Expectancy in LRR MSE : {mse:.4f}")
print(f"Life Expectancy in LRR RMSE: {rmse:.4f}")
# Out:
# Selected Regression Parameters LRR:
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': 3}
#
# Life Expectancy in LRR R²: 0.8031
# Life Expectancy in LRR MAE : 2.1952
# Life Expectancy in LRR MSE : 7.8429
# Life Expectancy in LRR RMSE: 2.8005
